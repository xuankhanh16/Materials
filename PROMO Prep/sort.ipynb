# %%
arr = [8, 5, 2, 1, 3, 7, 9]

# %%
def insertion_sort(bruh):
    arr = bruh[:]
    for i in range (1, len(bruh)):
        key_element = arr[i]
        j = i-1

        while j>=0 and arr[j] > key_element:
            arr[j+1] = arr[j]
            j -= 1
        
        arr[j+1] = key_element
    print(arr)

print(arr)
insertion_sort(arr)
print(arr)
# Out:
# [8, 5, 2, 1, 3, 7, 9]
# [1, 2, 3, 5, 7, 8, 9]
# [8, 5, 2, 1, 3, 7, 9]

# %%
def bubble_sort(bruh):
    arr = bruh
    swap = False
    n = len(arr)
    for i in range (n-1):
        for j in range (n - i - 1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
                swap = True
        if swap == False:
            break
    return arr
    
print(arr)
bubble_sort(arr)
print(arr)
# Out:
# [1, 2, 3, 5, 7, 8, 9]
# [1, 2, 3, 5, 7, 8, 9]

# %%
import random

def quick_sort(list):

    n = len(list)
    if n <= 1:
        return list

    left = []
    middle = []
    right = []

    x = random.randint(0,n-1) #simply cus list is 0 index
    pivot = list[x]
    for element in list:
        if (element > pivot):
            right.append(element)
        elif (element < pivot):
            left.append(element)
        else:
            middle.append(element)

    return quick_sort(left) + middle  + quick_sort(right)


print(arr)
print(quick_sort(arr))
print(arr)
# Out:
# [8, 5, 2, 1, 3, 7, 9]
# [1, 2, 3, 5, 7, 8, 9]
# [8, 5, 2, 1, 3, 7, 9]

# %%
def merge_sort(list):
    if len(list) <= 1:
        return list
    
    mid = len(list) // 2
    left = list[:mid]
    right = list[mid:]

    left = merge_sort(left)
    right = merge_sort(right)

    return merge(left, right)


def merge (left, right):
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    return result + left[i:] + right[j:]


left = [3, 5, 8]
right = [4, 9, 12]

arr = [8, 5, 2, 1, 3, 7, 9]

print(arr)
print(merge_sort(arr))
# Out:
# [8, 5, 2, 1, 3, 7, 9]
# [1, 2, 3, 5, 7, 8, 9]
