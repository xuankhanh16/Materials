# %% [markdown]
# # Exercise 7.5 2021/ALVL/P1/Q4 (Modified)
# A competition has three qualifying rounds. Competitors could score up to 100 points in each round. Each competitor has a unique ID number. The competitor's ID, name, and the scores for
# each round are held in two files in the `resources` folder provided with this question.
#
# There are two files:
# - `Ex_7_4_competitor.csv`
# - `Ex_7_4_scores.csv`
#
# where the first lines of the files contained a header that indicates the competitor's ID, name, and the scores for each round.
#
# Not every competitor competed in all three rounds, but they did all compete in round 1.
#
# ## Task 1
# Write a Python program and the necessary files to create a web application. The web application offers the following menu options:
#
# <center>
#
# | Navigation |
# |----------------|
# |Round 1 Scores |
# | Round 2 Scores |
# | Round 3 Scores |
# | Mean Scores    |
# | Qualifiers     |
#
# </center>
#
# Save your program code as
#
# `EXERCISE_7_5_1.py`
#
# with any additional files / sub-folders as needed in a folder named
#
# `EXERCISE_7_5_1`
#
# Run the web application and save the output of the program as
# `EXERCISE_7_5_1.html` <div style="text-align: right">[3]</div>

# %%
from flask import Flask, render_template


app = Flask(__name__)

@app.route('/')
def base():
    return render_template('base.html')

@app.route('/round1')
def round1():
    return render_template('round1.html')

@app.route('/round2')
def round2():
    return render_template('round2.html')

@app.route('/round3')
def round3():
    return render_template('round3.html')

@app.route('/mean')
def mean():
    return render_template('mean.html')

@app.route('/qualifiers')
def qualifiers():
    return render_template('qualifiers.html')

app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [08/Jul/2025 10:52:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Jul/2025 10:52:04] "GET /round1.html HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Jul/2025 10:52:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Jul/2025 10:52:07] "GET /round2.html HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Jul/2025 10:52:09] "GET / HTTP/1.1" 200 -

# %% [markdown]
# ## Task 2
# Write a function `task_2()` that accepts an integer `n` that represents a round number.  The function return a list `[<NAME>,<SCORE>]` containing
# - competitor names, and
# - their scores for that particular round such that only those who had a score for that round is included in the list.
#
# The elements in the list should be arranged in descending order of scores.
#
# The content of the list generated by `task_2()` should be shown on a web page in a table that:
# - lists the name of each competitor and their score
# - has the results shown in descending order of the competitor's score.
#
# The resulting web page for each round should be accessed from the corresponding menu option from Task 1.
#
# Save your program code as
#
# `EXERCISE_7_5_2.py`
#
# with any additional files / sub-folders as needed in a folder named
#
# `EXERCISE_7_5_2`
#
# <div style="text-align: right">[6]</div>
#
# Run the web application and save the output of the program as
#
# `EXERCISE_7_5_2_1.html`
#
# `EXERCISE_7_5_2_2.html`
#
# `EXERCISE_7_5_2_3.html`
#
# <div style="text-align: right">[2]</div>

# %%
from flask import Flask, render_template
import csv

app = Flask(__name__)

def task_2(n):
    competitors = []
    results = []

    # Load competitor info (skip header)
    with open('Ex_7_4_competitor.csv') as f:
        reader = csv.reader(f)
        next(reader)  # skip header
        for row in reader:
            competitors.append(row)  # row = [id, name]

    # Load scores for round n (skip header)
    with open('Ex_7_4_scores.csv') as f:
        reader = csv.reader(f)
        next(reader)  # skip header
        for row in reader:
            round_num = int(row[1])
            if round_num == n:
                competitor_id = row[0]
                score = int(row[2])
                # Find name by ID
                name = "Unknown"
                for comp in competitors:
                    if comp[0] == competitor_id:
                        name = comp[1]
                        break
                results.append([name, score])
    results.sort(key=lambda x: x[1], reverse=True)
    return(results)


#task_2(4)


@app.route('/')
def index():
    return render_template("base.html")

@app.route('/round<int:n>')
def show_round(n):
    results = task_2(n)
    return render_template(f"round{n}.html", round_number=n, results=results)

@app.route('/mean')
def show_mean(n):

app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [09/Jul/2025 08:01:00] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2025 08:01:00] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Jul/2025 08:01:03] "GET /round1 HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2025 08:01:05] "GET /round2 HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2025 08:01:07] "GET /round3 HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2025 08:01:08] "GET /mean.html HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Jul/2025 08:01:11] "GET /round3 HTTP/1.1" 200 -

# %% [markdown]
# ## Task 3
# Write a function `task_3()` that return a list `[<NAME>,<MEAN_SCORE>]` containing
# - competitor names,
# - the mean score for each competitor, based on the number of rounds in which they competed.
#
# The elements in the list should be arranged in ascending alphabetical order of the competitor's name.
#
# The content of the list generated by `task_3()` should be shown on a web page in a table that:
# - lists the name of each competitor and their mean score (to 2 decimal places)
# - has the results shown in ascending alphabetical order of the competitor's name.
#
# The resulting web page should be accessed from the corresponding menu option from Task 1.
#
# Save your program code as
#
# `EXERCISE_7_5_3.py`
#
# with any additional files / sub-folders as needed in a folder named
#
# `EXERCISE_7_5_3`
#
# <div style="text-align: right">[6]</div>
#
# Run the web application and save the output of the program as
#
# `EXERCISE_7_5_3.html`
#
# <div style="text-align: right">[2]</div>

# %%
from flask import Flask, render_template
import csv

app = Flask(__name__)

def task_2(n):
    competitors = []
    results = []

    # Load competitor info (skip header)
    with open('Ex_7_4_competitor.csv') as f:
        reader = csv.reader(f)
        next(reader)  # skip header
        for row in reader:
            competitors.append(row)  # row = [id, name]

    # Load scores for round n (skip header)
    with open('Ex_7_4_scores.csv') as f:
        reader = csv.reader(f)
        next(reader)  # skip header
        for row in reader:
            round_num = int(row[1])
            if round_num == n:
                competitor_id = row[0]
                score = int(row[2])
                # Find name by ID
                name = "Unknown"
                for comp in competitors:
                    if comp[0] == competitor_id:
                        name = comp[1]
                        break
                results.append([name, score])
    results.sort(key=lambda x: int(x[1]), reverse=True)
    return(results)


def mean_calc():
    indiv_score= []
    mean_score = []
    total_score = {}
    counts = {}
    id_list = []
    with open("Ex_7_4_scores.csv") as f:
        reader = csv.reader(f)
        next(reader)
        for row in reader:
            id_ = row[0]
            score = int(row[2])
            indiv_score.append([id_, score])
    for entry in indiv_score:
        cid = entry[0]
        if cid in id_list:
            total_score [cid] += entry[1]
            counts[cid] +=1
        else:
            id_list.append(cid)
            total_score [cid] = entry[1]
            counts [cid] = 1
    
    for index in id_list:
        mean = total_score[index] / counts [index]
        mean_score.append([index, mean])

    mean_score_dict = {cid: mean for cid, mean in mean_score}
    
    mean_calc_name = {}
    with open("Ex_7_4_competitor.csv") as file:
        reader = csv.reader(file)
        next(reader)
        for row in reader:
            idi = row[0]
            name = row [1]
            mean_calc_name [name] = round(mean_score_dict[idi])
    sorted_mean_calc_name = dict(sorted(mean_calc_name.items()))
    return list(sorted_mean_calc_name.items())
            



@app.route('/')
def index():
    return render_template("base.html")

@app.route('/round<int:n>')
def show_round(n):
    results = task_2(n)
    return render_template(f"round.html", round_number=n, results=results)

@app.route('/mean')
def show_mean():
    results = mean_calc()
    return render_template("mean.html", results = results)

app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [14/Jul/2025 15:56:22] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Jul/2025 15:56:22] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [14/Jul/2025 15:56:23] "GET /round1 HTTP/1.1" 200 -
